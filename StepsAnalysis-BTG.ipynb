# %% [markdown]
# **Author:** Brayden Guelich
# **Metric:** Number of Steps Per Neighborhood
#
# I chose this metric to measure the number of steps throughout the neighborhoods of Pittbsurgh. As I was born and raised in the area, I was very curious to see if my personal experience would have any consistency with official data. For this project, I ranked the neighborhoods with more steps to be lower on the list, and the ones with fewer on the upper end.

# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt

# %%
steps_data = pd.read_csv("https://data.wprdc.org/datastore/dump/43f40ca4-2211-4a12-8b4f-4d052662bb64")

# %%
steps_data
# Out:
#               id                                     name  \
# 0      326501686                          10 Wakefield St
# 1      527853474                        1005 St Martin St
# 2     1074700399                        1017 St Martin St
# 3       50987987  30th St from Bigelow Blvd to Leander St
# 4      173445306    30th St from Paulowna to Bigelow Blvd
# ...          ...                                      ...
# 1009   436649994                             Frick Park 7
# 1010  1118777905                             Niagara Park
# 1011   804870832                          Wightman Park 1
# 1012   455122184                          Wightman Park 2
# 1013  1706866582                          Wightman Park 3
#
#      maintenance_responsibility   installed  material  length  \
# 0                  3rd Division         NaN  Concrete    53.0
# 1                  4th Division         NaN  Concrete    33.0
# 2                  4th Division         NaN  Concrete    52.0
# 3                  3rd Division  1948-01-01  Concrete   106.0
# 4                  6th Division  1948-01-01  Concrete   204.0
# ...                         ...         ...       ...     ...
# 1009            Parks - Eastern         NaN     Stone     NaN
# 1010           Parks - Schenley         NaN  Concrete     NaN
# 1011            Parks - Eastern         NaN  Concrete     NaN
# 1012            Parks - Eastern         NaN  Concrete     NaN
# 1013            Parks - Eastern         NaN  Concrete     NaN
#
#       number_of_steps  schools_count  school_score  total_population  ...  \
# 0                 8.0            0.0         100.0             367.0  ...
# 1                24.0            NaN           NaN               NaN  ...
# 2                 4.0            NaN           NaN               NaN  ...
# 3               106.0            0.0         100.0             235.0  ...
# 4                85.0            1.0           4.0             422.0  ...
# ...               ...            ...           ...               ...  ...
# 1009              NaN            NaN           NaN               NaN  ...
# 1010              NaN            NaN           NaN               NaN  ...
# 1011              NaN            NaN           NaN               NaN  ...
# 1012              NaN            NaN           NaN               NaN  ...
# 1013              NaN            NaN           NaN               NaN  ...
#
#              neighborhood  council_district  ward        tract  \
# 0           South Oakland               3.0     4  42003040900
# 1       South Side Slopes               3.0    17  42003170600
# 2       South Side Slopes               3.0    17  42003170600
# 3       Bedford Dwellings               7.0     6  42003060500
# 4             Polish Hill               7.0     6  42003060500
# ...                   ...               ...   ...          ...
# 1009         Point Breeze               9.0    14  42003981100
# 1010        South Oakland               3.0     4  42003040900
# 1011  Squirrel Hill North               8.0    14  42003140300
# 1012  Squirrel Hill North               8.0    14  42003140300
# 1013  Squirrel Hill North               8.0    14  42003140300
#
#      public_works_division pli_division  police_zone  fire_zone   latitude  \
# 0                        3            4            4       2-11  40.430926
# 1                        3           17            3        4-6  40.422410
# 2                        3           17            3        4-6  40.422471
# 3                        3            6            2       2-24  40.454787
# 4                        6            6            2        2-6  40.455470
# ...                    ...          ...          ...        ...        ...
# 1009                     3           14            4       3-14  40.442094
# 1010                     3            4            4       2-10  40.434592
# 1011                     3           14            4        2-8  40.443513
# 1012                     3           14            4       2-18  40.443099
# 1013                     3           14            4       2-18  40.443067
#
#       longitude
# 0    -79.957090
# 1    -79.988215
# 2    -79.987604
# 3    -79.968453
# 4    -79.968725
# ...         ...
# 1009 -79.900003
# 1010 -79.960035
# 1011 -79.927747
# 1012 -79.926734
# 1013 -79.926439
#
# [1014 rows x 25 columns]

# %%
steps_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          1014 non-null   int64
#  1   name                        1014 non-null   object
#  2   maintenance_responsibility  999 non-null    object
#  3   installed                   450 non-null    object
#  4   material                    1009 non-null   object
#  5   length                      853 non-null    float64
#  6   number_of_steps             736 non-null    float64
#  7   schools_count               556 non-null    float64
#  8   school_score                556 non-null    float64
#  9   total_population            556 non-null    float64
#  10  transit_rider_count         556 non-null    float64
#  11  transit_score               556 non-null    float64
#  12  detour_score                556 non-null    float64
#  13  overall_score               558 non-null    float64
#  14  image                       872 non-null    object
#  15  neighborhood                1014 non-null   object
#  16  council_district            1013 non-null   float64
#  17  ward                        1014 non-null   int64
#  18  tract                       1014 non-null   int64
#  19  public_works_division       1014 non-null   int64
#  20  pli_division                1014 non-null   int64
#  21  police_zone                 1014 non-null   int64
#  22  fire_zone                   1014 non-null   object
#  23  latitude                    1014 non-null   float64
#  24  longitude                   1014 non-null   float64
# dtypes: float64(12), int64(6), object(7)
# memory usage: 198.2+ KB

# %%
neigh = steps_data['neighborhood'].unique()
print(neigh)
# Out:
# ['South Oakland' 'South Side Slopes' 'Bedford Dwellings' 'Polish Hill'
#  'Upper Lawrenceville' 'Stanton Heights' 'Squirrel Hill South' 'Sheraden'
#  'Greenfield' 'West Oakland' 'Upper Hill' 'Beechview'
#  'Mount Oliver Borough' 'Allentown' 'Elliott' 'Banksville' 'Carrick'
#  'Spring Garden' 'Marshall-Shadeland' 'California-Kirkbride' 'Morningside'
#  'Brookline' 'Troy Hill' 'Brighton Heights' 'Squirrel Hill North'
#  'Beltzhoover' 'Hazelwood' 'Strip District' 'Perry South' 'Perry North'
#  'Central Oakland' 'Spring Hill-City View' 'Knoxville' 'Homewood North'
#  'Mt. Oliver' 'North Oakland' 'Bon Air' 'Middle Hill' 'Fineview'
#  'Bloomfield' 'Crafton Heights' 'East Allegheny' 'Arlington'
#  'Mount Washington' 'Westwood' 'Overbrook' 'East Hills'
#  'Central Northside' 'Point Breeze' 'Highland Park' 'Chartiers City'
#  'West End' 'Ridgemont' 'Terrace Village' 'Garfield' 'Duquesne Heights'
#  'St. Clair' 'Esplen' 'Oakwood' 'Lincoln Place' 'Central Lawrenceville'
#  'Windgap' 'Glen Hazel' 'Lincoln-Lemington-Belmar' 'Larimer'
#  'Crawford-Roberts' 'East Carnegie' 'South Side Flats' 'Shadyside' 'Bluff'
#  'Allegheny Center' 'Manchester' 'Lower Lawrenceville' 'South Shore'
#  'Regent Square']

# %%
s = []
n = []
z = []
#fills array of steps 
for i in range(1010):
    s.append(steps_data.loc[i,'number_of_steps'])
#print(s)
s=s[-1010:]
#fills array of neighborhoods
for j in range(1010):
    n.append(steps_data.loc[j,'neighborhood'])
#print(n)
n=n[-1010:]

for i in range (1010):
    if str(s[i]).lower() == 'nan':
        s[i] = 0
    s[i] = int(s[i])
#fills array of pairs 
for i in range (1010):
    z.append([n[i],s[i]])
    
z=z[2:-1]
z.sort(key=lambda x:x[1]) 

#print(z)

# %%
#Adds all Steps in each neighborhood
stepsum = 0
finalList = []
for x in (neigh):
    for i in (z):
        if i[0] == x:
            stepsum += i[1]
    finalList.append([x,stepsum]) 
    stepsum = 0
finalList.sort(key=lambda x:x[1])
print(finalList)
# Out:
# [['Manchester', 0], ['Lower Lawrenceville', 0], ['Regent Square', 0], ['South Shore', 4], ['Mount Oliver Borough', 9], ['Central Lawrenceville', 9], ['Windgap', 16], ['Allegheny Center', 28], ['Esplen', 48], ['Shadyside', 50], ['East Carnegie', 52], ['St. Clair', 53], ['South Side Flats', 56], ['Bon Air', 57], ['Strip District', 65], ['Highland Park', 66], ['North Oakland', 72], ['Ridgemont', 76], ['Chartiers City', 81], ['Crawford-Roberts', 88], ['Larimer', 93], ['Squirrel Hill South', 105], ['Terrace Village', 106], ['Mt. Oliver', 116], ['West End', 127], ['Oakwood', 129], ['Knoxville', 151], ['Glen Hazel', 151], ['Point Breeze', 156], ['Bloomfield', 161], ['East Hills', 169], ['Bluff', 179], ['Bedford Dwellings', 234], ['Lincoln Place', 248], ['Squirrel Hill North', 252], ['South Oakland', 330], ['Morningside', 333], ['Central Northside', 333], ['Banksville', 338], ['Allentown', 358], ['Central Oakland', 361], ['Beltzhoover', 391], ['Arlington', 440], ['Westwood', 463], ['Crafton Heights', 478], ['West Oakland', 485], ['East Allegheny', 487], ['Lincoln-Lemington-Belmar', 495], ['Middle Hill', 497], ['Duquesne Heights', 504], ['Brighton Heights', 511], ['Spring Garden', 526], ['Homewood North', 565], ['Upper Hill', 664], ['Garfield', 672], ['California-Kirkbride', 742], ['Stanton Heights', 774], ['Upper Lawrenceville', 783], ['Carrick', 794], ['Perry North', 848], ['Sheraden', 887], ['Spring Hill-City View', 946], ['Elliott', 950], ['Overbrook', 1012], ['Polish Hill', 1037], ['Troy Hill', 1115], ['Fineview', 1121], ['Brookline', 1246], ['Marshall-Shadeland', 1349], ['Mount Washington', 1363], ['Hazelwood', 1374], ['Greenfield', 1472], ['Perry South', 1843], ['Beechview', 2473], ['South Side Slopes', 4051]]

# %%
# Seperating Matched Data by Index of Each Element
sortedSteps = []
for x in (finalList):
    sortedSteps.append(x[1])
print(sortedSteps)
sortedNeigh = []
for x in (finalList):
    sortedNeigh.append(x[0])
print(sortedNeigh)
# Out:
# [0, 0, 0, 4, 9, 9, 16, 28, 48, 50, 52, 53, 56, 57, 65, 66, 72, 76, 81, 88, 93, 105, 106, 116, 127, 129, 151, 151, 156, 161, 169, 179, 234, 248, 252, 330, 333, 333, 338, 358, 361, 391, 440, 463, 478, 485, 487, 495, 497, 504, 511, 526, 565, 664, 672, 742, 774, 783, 794, 848, 887, 946, 950, 1012, 1037, 1115, 1121, 1246, 1349, 1363, 1374, 1472, 1843, 2473, 4051]
# ['Manchester', 'Lower Lawrenceville', 'Regent Square', 'South Shore', 'Mount Oliver Borough', 'Central Lawrenceville', 'Windgap', 'Allegheny Center', 'Esplen', 'Shadyside', 'East Carnegie', 'St. Clair', 'South Side Flats', 'Bon Air', 'Strip District', 'Highland Park', 'North Oakland', 'Ridgemont', 'Chartiers City', 'Crawford-Roberts', 'Larimer', 'Squirrel Hill South', 'Terrace Village', 'Mt. Oliver', 'West End', 'Oakwood', 'Knoxville', 'Glen Hazel', 'Point Breeze', 'Bloomfield', 'East Hills', 'Bluff', 'Bedford Dwellings', 'Lincoln Place', 'Squirrel Hill North', 'South Oakland', 'Morningside', 'Central Northside', 'Banksville', 'Allentown', 'Central Oakland', 'Beltzhoover', 'Arlington', 'Westwood', 'Crafton Heights', 'West Oakland', 'East Allegheny', 'Lincoln-Lemington-Belmar', 'Middle Hill', 'Duquesne Heights', 'Brighton Heights', 'Spring Garden', 'Homewood North', 'Upper Hill', 'Garfield', 'California-Kirkbride', 'Stanton Heights', 'Upper Lawrenceville', 'Carrick', 'Perry North', 'Sheraden', 'Spring Hill-City View', 'Elliott', 'Overbrook', 'Polish Hill', 'Troy Hill', 'Fineview', 'Brookline', 'Marshall-Shadeland', 'Mount Washington', 'Hazelwood', 'Greenfield', 'Perry South', 'Beechview', 'South Side Slopes']

# %%
#Inserting Matched Data Into Data Frame
steps_data['Total_Steps'] = pd.Series(sortedSteps)
steps_data['Neighborhoods_In_Order'] = pd.Series(sortedNeigh)


#Taking Desired Columns and Creating New DataFrame
selected_columns = steps_data[['Neighborhoods_In_Order','Total_Steps']]
new_df = selected_columns.copy()


#Graph
plotData = new_df.dropna()
plotData.plot(x = 'Neighborhoods_In_Order', y = 'Total_Steps', kind = 'bar')
plt.rcParams["figure.figsize"] = (50,20)
plt.rc('xtick', labelsize=40)
plt.rc('ytick', labelsize=40)
plt.title('Pittsburgh Neighborhoods and Steps')
plt.xlabel('Neighborhoods')
plt.ylabel('# of Steps')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     805             try:
# --> 806                 cval = self.validate[key](val)
#     807             except ValueError as ve:
#
# KeyError: 'xlabel.labelsize'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/__init__.py in rc(group, **kwargs)
#    1097             try:
# -> 1098                 rcParams[key] = v
#    1099             except KeyError:
#
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     810         except KeyError:
# --> 811             raise KeyError(
#     812                 f"{key} is not a valid rc parameter (see rcParams.keys() for "
#
# KeyError: 'xlabel.labelsize is not a valid rc parameter (see rcParams.keys() for a list of valid parameters)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-750218ebe428> in <module>
#      18 plt.xlabel('Neighborhoods')
#      19 plt.ylabel('# of Steps')
# ---> 20 plt.rc('xlabel', labelsize=40)
#      21 plt.rc('ylabel', labelsize=40)
#      22 plt.show()
#
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/pyplot.py in rc(group, **kwargs)
#     318 @docstring.copy(matplotlib.rc)
#     319 def rc(group, **kwargs):
# --> 320     matplotlib.rc(group, **kwargs)
#     321
#     322
#
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/__init__.py in rc(group, **kwargs)
#    1098                 rcParams[key] = v
#    1099             except KeyError:
# -> 1100                 raise KeyError(('Unrecognized key "%s" for group "%s" and '
#    1101                                 'name "%s"') % (key, g, name))
#    1102
#
# KeyError: 'Unrecognized key "xlabel.labelsize" for group "xlabel" and name "labelsize"'

# %% [markdown]
# **Conclusion:**
# The "best" neioghborhood is a three way tie between Manchester, Lower Lawrenceville, and Regent Square. If we drop those, the best would be south shore with 4 steps in total. The "worst" neighorhood was South Side Slopes by a signifcant 1500 step margin. Following was Beechview and Perry South with 2473 and 1843 respectively. In the median, Oakland as a whole. Oakland is a good center piece as it has North and South that are both in the in the upper precentiles in terms of "bestness".
